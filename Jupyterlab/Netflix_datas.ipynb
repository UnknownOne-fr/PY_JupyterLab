# %%
import pandas as pd
df = pd.read_csv("netflix_titles.csv")

# %%
df
# Out:
#      show_id     type                                    title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                     7:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7782   s7783    Movie                                     Zozo
# 7783   s7784    Movie                                   Zubaan
# 7784   s7785    Movie                        Zulu Man in Japan
# 7785   s7786  TV Show                    Zumbo's Just Desserts
# 7786   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                director                                               cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
df["country"].value_counts()
# Out:
# United States                                          2555
# India                                                   923
# United Kingdom                                          397
# Japan                                                   226
# South Korea                                             183
#                                                        ...
# United Arab Emirates, United States, United Kingdom       1
# United Kingdom, France, Germany, Spain                    1
# Egypt, Algeria                                            1
# United States, United Kingdom, Canada                     1
# Netherlands, Belgium, United Kingdom, United States       1
# Name: country, Length: 681, dtype: int64

# %%
df.groupby("country")["release_year"].value_counts(bins = 3)
# Out:
# country
# Argentina                                            (2008.333, 2020.0]      45
#                                                      (1996.667, 2008.333]     4
#                                                      (1984.964, 1996.667]     1
# Argentina, Brazil, France, Poland, Germany, Denmark  (2016.328, 2017.672]     1
#                                                      (2014.982, 2016.328]     0
#                                                                              ..
# West Germany                                         (1975.022, 1976.341]     0
#                                                      (1977.659, 1978.977]     0
# Zimbabwe                                             (2016.328, 2017.672]     1
#                                                      (2014.982, 2016.328]     0
#                                                      (2017.672, 2019.017]     0
# Name: release_year, Length: 2043, dtype: int64

# %%
df["country"].value_counts().head(3)
# Out:
# United States     2555
# India              923
# United Kingdom     397
# Name: country, dtype: int64

# %%
df["country"].value_counts().head(3).tolist()
# Out:
# [2555, 923, 397]

# %%
df["country"].value_counts()[:3].to_dict()
# Out:
# {'United States': 2555, 'India': 923, 'United Kingdom': 397}

# %%
df["release_year"].value_counts(ascending=False)[:10]
# Out:
# 2018    1121
# 2017    1012
# 2019     996
# 2016     882
# 2020     868
# 2015     541
# 2014     334
# 2013     267
# 2012     219
# 2010     173
# Name: release_year, dtype: int64

# %%
df["release_year"].value_counts().sort_index(ascending=False)[:10]
# Out:
# 2021      31
# 2020     868
# 2019     996
# 2018    1121
# 2017    1012
# 2016     882
# 2015     541
# 2014     334
# 2013     267
# 2012     219
# Name: release_year, dtype: int64

# %%
df["release_year"].value_counts().sort_index(ascending=False)[:10].to_dict()
# Out:
# {2021: 31,
#  2020: 868,
#  2019: 996,
#  2018: 1121,
#  2017: 1012,
#  2016: 882,
#  2015: 541,
#  2014: 334,
#  2013: 267,
#  2012: 219}

# %%
df["director"].unique().tolist()[1:11]
# Out:
# ['Jorge Michel Grau',
#  'Gilbert Chan',
#  'Shane Acker',
#  'Robert Luketic',
#  'Serdar Akar',
#  'Yasir Al Yasiri',
#  'Kevin Reynolds',
#  'Shravan Kumar',
#  'Vikram Bhatt',
#  'Zak Hilditch']

# %%
df.director.dropna().unique().tolist()
# Out:
# ['Jorge Michel Grau',
#  'Gilbert Chan',
#  'Shane Acker',
#  'Robert Luketic',
#  'Serdar Akar',
#  'Yasir Al Yasiri',
#  'Kevin Reynolds',
#  'Shravan Kumar',
#  'Vikram Bhatt',
#  'Zak Hilditch',
#  'Diego Enrique Osorno',
#  'Nottapon Boonprakob',
#  'John Suits',
#  'Kunle Afolayan',
#  'Paul Greengrass',
#  'Swapnaneel Jayakar',
#  'Onir',
#  'Vijay Milton',
#  'Santwana Bardoloi',
#  'Atanu Ghosh',
#  'Lyric R. Cabral, David Felix Sutcliffe',
#  'Cho Il',
#  'Sabina Fedeli, Anna Migotto',
#  'Michael Margolis',
#  'Rako Prijanto',
#  'Fernando Lebrija',
#  'Michael Kennedy',
#  'Robert McCullough Jr.',
#  'Cristina Jacob',
#  'Frank Ariza',
#  'Muharrem Gülmez',
#  'Óskar Thór Axelsson',
#  'Ozan Açıktan',
#  'Kenneth Gyang',
#  'Karyn Kusama',
#  'Adam Deyoe',
#  'Leif Tilden',
#  'Adze Ugah',
#  'Nicolas Brossette',
#  'Roland Emmerich',
#  'Marcel Barrena',
#  'Melinda Janko',
#  'Jastis Arimba',
#  'Shrihari Sathe',
#  'Sam Upton',
#  'Victor Zarcoff',
#  'Daniel Stamm',
# ...

# %%
df["duration"]
# Out:
# 0       4 Seasons
# 1          93 min
# 2          78 min
# 3          80 min
# 4         123 min
#           ...
# 7782       99 min
# 7783      111 min
# 7784       44 min
# 7785     1 Season
# 7786       90 min
# Name: duration, Length: 7787, dtype: object

# %%
df["duration"].str.replace("min","")
# Out:
# 0       4 Seasons
# 1             93
# 2             78
# 3             80
# 4            123
#           ...
# 7782          99
# 7783         111
# 7784          44
# 7785     1 Season
# 7786          90
# Name: duration, Length: 7787, dtype: object

# %%
df["duration"][df["duration"].str.contains("min")].str.replace("min","")
# Out:
# 1        93
# 2        78
# 3        80
# 4       123
# 6        95
#         ...
# 7781     88
# 7782     99
# 7783    111
# 7784     44
# 7786     90
# Name: duration, Length: 5377, dtype: object

# %%
df2 = df["duration"][df["duration"].str.contains("min")].str.replace("min","")
type(df2)
# Out:
# pandas.core.series.Series

# %%
df3 = df2.to_frame()

# %%
df3
# Out:
#      duration
# 1         93
# 2         78
# 3         80
# 4        123
# 6         95
# ...       ...
# 7781      88
# 7782      99
# 7783     111
# 7784      44
# 7786      90
#
# [5377 rows x 1 columns]

# %%
df3["duration"].astype(float).mean()
# Out:
# 99.30797842663195

# %%
df["duration"][df["duration"].str.contains("min")].str.replace("min","").to_frame().astype(float).mean()
# Out:
# duration    99.307978
# dtype: float64
